# %% [markdown]
# #Time series Decompose (level, trend, seasonality, and noise)

# %%
import pandas as pd

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# !wget -q "https://raw.githubusercontent.com/jbrownlee/Datasets/master/airline-passengers.csv"

# %%
# multiplicative decompose time series
series = pd.read_csv('airline-passengers.csv', header=0, index_col=0, parse_dates=True, squeeze=True)
series[:5]
# Out:
# Month
# 1949-01-01    112
# 1949-02-01    118
# 1949-03-01    132
# 1949-04-01    129
# 1949-05-01    121
# Name: Passengers, dtype: int64

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
result = seasonal_decompose(series, model='multiplicative')
result

# %%
result.plot()
pyplot.show()

# %% [markdown]
# Widzimy, że informacje o trendzie i sezonowości wyodrębnione z szeregu wydają się rozsądne, a dane są również dostępne w danych, a na wykresie można zaobserwować okresy dużej zmienności we wczesnych i późniejszych latach szeregu.
