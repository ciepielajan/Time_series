# %% [markdown]
# <a href="https://colab.research.google.com/github/ciepielajan/Time_series/blob/main/Times_plot_trend_seasonal_observed_residual.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import random 
from statsmodels.tsa.seasonal import seasonal_decompose
import matplotlib.pyplot as plt

# %%
# additive decompose a simulated additive time series
series = [i+random.randrange(10) for i in range(1,100)]
result = seasonal_decompose(series, model='additive', freq=1)

fig = plt.figure(figsize=(20,10))
result.plot()
plt.show()
